# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
coffee_data=pd.read_csv("D:\index.csv")
import warnings
warnings.filterwarnings("ignore")

# %%
coffee_data.head()
# Out:
#          date                 datetime cash_type                 card  money  \
# 0  2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name
# 0          Latte
# 1  Hot Chocolate
# 2  Hot Chocolate
# 3      Americano
# 4          Latte

# %%
coffee_data.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
coffee_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         1133 non-null   object
#  1   datetime     1133 non-null   object
#  2   cash_type    1133 non-null   object
#  3   card         1044 non-null   object
#  4   money        1133 non-null   float64
#  5   coffee_name  1133 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 53.2+ KB

# %%
coffee_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1128    False
# 1129    False
# 1130    False
# 1131    False
# 1132    False
# Length: 1133, dtype: bool

# %%
coffee_data.duplicated().sum()
# Out:
# 0

# %%
coffee_data.describe().T
# Out:
#         count       mean       std    min   25%    50%    75%   max
# money  1133.0  33.105808  5.035366  18.12  28.9  32.82  37.72  40.0

# %%
coffee_data.loc[:,["cash_type",'card','coffee_name']].describe().T
# Out:
#             count unique                  top  freq
# cash_type    1133      2                 card  1044
# card         1044    446  ANON-0000-0000-0012    88
# coffee_name  1133      8  Americano with Milk   268

# %%
coffee_data[coffee_data["card"].isnull()]['cash_type'].value_counts()
# Out:
# cash_type
# cash    89
# Name: count, dtype: int64

# %%
coffee_data['cash_type'].hist()
# Out:
# <Axes: >

# %%
coffee_data['cash_type'].value_counts(normalize=True)*100
# Out:
# cash_type
# card    92.144748
# cash     7.855252
# Name: proportion, dtype: float64

# %%
pd.DataFrame(coffee_data['coffee_name'].value_counts(normalize=True).sort_values(ascending=False).round(3)*100)
# Out:
#                      proportion
# coffee_name
# Americano with Milk        23.7
# Latte                      21.4
# Cappuccino                 17.3
# Americano                  14.9
# Cortado                     8.7
# Hot Chocolate               6.5
# Espresso                    4.3
# Cocoa                       3.1

# %%
coffee_data['date']=pd.to_datetime(coffee_data['date'])
coffee_data['datetime']=pd.to_datetime(coffee_data['datetime'])

# %%
coffee_data['month']=coffee_data['date'].dt.strftime("%y-%m")
coffee_data['day']=coffee_data['date'].dt.strftime('%w')
coffee_data['hour']=coffee_data['datetime'].dt.strftime("%H")

# %%
coffee_data.head()
# Out:
#         date                datetime cash_type                 card  money  \
# 0 2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1 2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2 2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3 2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4 2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
#
#      coffee_name  month day hour
# 0          Latte  24-03   5   10
# 1  Hot Chocolate  24-03   5   12
# 2  Hot Chocolate  24-03   5   12
# 3      Americano  24-03   5   13
# 4          Latte  24-03   5   13

# %%
coffee_data['date'].max(),coffee_data['date'].min()
# Out:
# (Timestamp('2024-07-31 00:00:00'), Timestamp('2024-03-01 00:00:00'))

# %%
revenue_data=coffee_data.groupby(["coffee_name"]).sum(['money']).reset_index().sort_values(by='money',ascending=False)

# %%
plt.figure(figsize=(12,6))
axis=sns.barplot(data=(revenue_data),x='money',y='coffee_name',color='purple')
axis.bar_label(axis.containers[0],fontsize=8)
plt.xlabel("Revenue")
# Out:
# Text(0.5, 0, 'Revenue')

# %%
monthly_sales=(coffee_data.groupby(['coffee_name','month'])
.count()['date']
.reset_index()
.rename(columns={'date':'count'})
.pivot(index='month',columns='coffee_name',values='count')
.reset_index()
)
monthly_sales
# Out:
# coffee_name  month  Americano  Americano with Milk  Cappuccino  Cocoa  \
# 0            24-03         36                   34          20      6
# 1            24-04         35                   42          43      6
# 2            24-05         48                   58          55      9
# 3            24-06         14                   69          46      5
# 4            24-07         36                   65          32      9
#
# coffee_name  Cortado  Espresso  Hot Chocolate  Latte
# 0                 30        10             22     48
# 1                 19         7             13     31
# 2                 17         8             14     58
# 3                 19        10             14     50
# 4                 14        14             11     56

# %%
monthly_sales.describe().T.loc[:,['min','max']]
# Out:
#                       min   max
# coffee_name
# Americano            14.0  48.0
# Americano with Milk  34.0  69.0
# Cappuccino           20.0  55.0
# Cocoa                 5.0   9.0
# Cortado              14.0  30.0
# Espresso              7.0  14.0
# Hot Chocolate        11.0  22.0
# Latte                31.0  58.0

# %%
plt.figure(figsize=(14,8))
sns.lineplot(data=monthly_sales,palette="tab10")
plt.legend(loc='upper left')
plt.xticks(ticks=range(len(monthly_sales['month'])), labels=monthly_sales['month'], rotation=45, ha='right', size='small')
plt.show()

# %%
weekday_sales=coffee_data.groupby(['day']).count()['date'].reset_index().rename(columns={'date':'count'})
weekday_sales
# Out:
#   day  count
# 0   0    151
# 1   1    151
# 2   2    185
# 3   3    165
# 4   4    164
# 5   5    163
# 6   6    154

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=weekday_sales,x='day',y='count',color='brown')
plt.xticks(ticks=range(len(weekday_sales['day'])),labels=['sun','mon','tues','wed','thurs','fri','sat'], rotation=45, ha='right',size='small')
plt.show()

# %%
daily_sales=coffee_data.groupby(['coffee_name','date']).count()['datetime'].reset_index().reset_index().rename(columns={'datetime':'count'}).pivot(index='date',columns='coffee_name',values='count').reset_index().fillna(0)
daily_sales
# Out:
# coffee_name       date  Americano  Americano with Milk  Cappuccino  Cocoa  \
# 0           2024-03-01        1.0                  4.0         0.0    1.0
# 1           2024-03-02        3.0                  3.0         0.0    0.0
# 2           2024-03-03        1.0                  2.0         0.0    1.0
# 3           2024-03-04        0.0                  1.0         0.0    0.0
# 4           2024-03-05        0.0                  0.0         0.0    1.0
# ..                 ...        ...                  ...         ...    ...
# 145         2024-07-27        0.0                  5.0         4.0    0.0
# 146         2024-07-28        0.0                  1.0         0.0    0.0
# 147         2024-07-29        3.0                  2.0         2.0    1.0
# 148         2024-07-30        2.0                 12.0         2.0    0.0
# 149         2024-07-31        2.0                  6.0         1.0    2.0
#
# coffee_name  Cortado  Espresso  Hot Chocolate  Latte
# 0                0.0       0.0            3.0    2.0
# 1                0.0       0.0            0.0    1.0
# 2                2.0       0.0            2.0    2.0
# 3                0.0       1.0            0.0    2.0
# 4                1.0       0.0            4.0    3.0
# ..               ...       ...            ...    ...
# 145              0.0       2.0            0.0    2.0
# 146              0.0       1.0            0.0    1.0
# 147              0.0       0.0            2.0    1.0
# 148              3.0       2.0            0.0    3.0
# 149              4.0       0.0            0.0    7.0
#
# [150 rows x 9 columns]

# %%
daily_sales.iloc[:,1:].describe().T.loc[:,['min','max']]
# Out:
#                      min   max
# coffee_name
# Americano            0.0   5.0
# Americano with Milk  0.0  12.0
# Cappuccino           0.0   9.0
# Cocoa                0.0   2.0
# Cortado              0.0   4.0
# Espresso             0.0   4.0
# Hot Chocolate        0.0   4.0
# Latte                0.0   7.0

# %%
hourly_sales=coffee_data.groupby(['hour']).count()['date'].reset_index().rename(columns={'date':'count'})
hourly_sales
# Out:
#    hour  count
# 0    07     13
# 1    08     44
# 2    09     50
# 3    10    133
# 4    11    103
# 5    12     87
# 6    13     78
# 7    14     76
# 8    15     65
# 9    16     77
# 10   17     77
# 11   18     75
# 12   19     96
# 13   20     54
# 14   21     70
# 15   22     35

# %%
sns.barplot(data=hourly_sales,x='hour',y='count',color='orange')
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
hourly_sales_by_coffee=(
coffee_data.groupby(['hour','coffee_name']).count()['date'].reset_index().rename(columns={'date':'count'}).pivot(index='hour',columns='coffee_name',values='count').fillna(0).reset_index()
)
hourly_sales_by_coffee
# Out:
# coffee_name hour  Americano  Americano with Milk  Cappuccino  Cocoa  Cortado  \
# 0             07        5.0                  4.0         1.0    0.0      1.0
# 1             08       10.0                  7.0         8.0    1.0      6.0
# 2             09        8.0                 16.0         6.0    1.0      5.0
# 3             10       20.0                 31.0        10.0    4.0      8.0
# 4             11       21.0                 25.0        16.0    1.0     13.0
# 5             12       14.0                 26.0        15.0    3.0      7.0
# 6             13       18.0                 18.0        10.0    2.0     12.0
# 7             14       15.0                 18.0        13.0    4.0      6.0
# 8             15       14.0                 15.0         8.0    0.0      3.0
# 9             16       10.0                 18.0        12.0    3.0     12.0
# 10            17        9.0                 11.0        18.0    4.0      6.0
# 11            18        9.0                 16.0        12.0    2.0      5.0
# 12            19        5.0                 18.0        34.0    2.0      5.0
# 13            20        1.0                 12.0        13.0    6.0      5.0
# 14            21        5.0                 25.0        13.0    1.0      3.0
# 15            22        5.0                  8.0         7.0    1.0      2.0
#
# coffee_name  Espresso  Hot Chocolate  Latte
# 0                 0.0            0.0    2.0
# 1                 0.0            0.0   12.0
# 2                 3.0            0.0   11.0
# 3                 2.0            7.0   51.0
# 4                 6.0            8.0   13.0
# 5                 6.0            3.0   13.0
# 6                 3.0            4.0   11.0
# 7                 5.0            2.0   13.0
# 8                 4.0            6.0   15.0
# 9                 5.0            4.0   13.0
# 10                4.0            7.0   18.0
# 11                5.0           10.0   16.0
# 12                1.0            9.0   22.0
# 13                3.0            6.0    8.0
# 14                1.0            3.0   19.0
# 15                1.0            5.0    6.0

# %%
fig,axs=plt.subplots(2,4,figsize=(20,10))
axs = axs.flatten()
for i, column in enumerate(hourly_sales_by_coffee.columns[1:]): 
    axs[i].bar(hourly_sales_by_coffee['hour'], hourly_sales_by_coffee[column])
    axs[i].set_title(f'{column}')
    axs[i].set_xlabel('Hour')
    axs[i].set_ylabel('Sales')

plt.tight_layout()
plt.show()
